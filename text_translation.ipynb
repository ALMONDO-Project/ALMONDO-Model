# %%
import json
import tqdm
import pandas as pd
import langdetect
from deep_translator import GoogleTranslator
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
#rcParams default settings
"https://matplotlib.org/stable/tutorials/introductory/customizing.html"

#rcParams settings
plt.style.use('ggplot')

rcParams['font.family'] = 'sans-serif'
rcParams['font.style'] = 'normal'

rcParams['figure.facecolor'] = 'white'

rcParams['savefig.bbox'] = 'tight'
rcParams['savefig.dpi'] = 300
rcParams['savefig.transparent'] = True

rcParams['axes.spines.right'] = False
rcParams['axes.spines.top'] = False
rcParams['axes.labelsize'] = 20
rcParams['axes.labelcolor'] = 'black'
rcParams['axes.edgecolor'] = 'grey'
rcParams['axes.linewidth'] = 3
rcParams['axes.facecolor'] = 'white'
rcParams['axes.titlepad'] = 4

rcParams['xtick.color'] = 'grey'
rcParams['ytick.color'] = 'grey'
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 0
rcParams['xtick.major.size'] = 5
rcParams['ytick.major.size'] = 0

rcParams['lines.linewidth'] = 3
rcParams['lines.markersize'] = 10

rcParams['grid.color'] = 'grey'
rcParams['grid.linewidth'] = 0.1

# %%
def get_language(text):
    try:
        return langdetect.detect(text)
    except KeyboardInterrupt as e:
        raise(e)
    except:
        return '<-- ERROR -->'
    
def get_translation(text):
    try:
        return GoogleTranslator(source='auto', target='en')\
          .translate(str(text))
    except KeyboardInterrupt as e:
        raise(e)
    except:
        return '<-- ERROR -->'

# %%
# Load the JSON file into a DataFrame
with open('data/out/filtered_tweets_2.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Create a DataFrame from the JSON data
df = pd.DataFrame(data)  # Transpose to set tweets as rows

df
# Out:
#                                      attachments  author_id  \
# 0     {'media_keys': ['13_1610292861630840833']}   51801586
# 1      {'media_keys': ['3_1612750081463095296']}   51801586
# 2     {'media_keys': ['13_1613112174939103235']}   51801586
# 3      {'media_keys': ['3_1613462741569736704']}   51801586
# 4     {'media_keys': ['13_1613831618141261825']}   51801586
# ...                                          ...        ...
# 6125   {'media_keys': ['3_1734966670068690949']}  156646851
# 6126   {'media_keys': ['3_1737133536577015808']}  156646851
# 6127   {'media_keys': ['3_1737491113206800384']}  156646851
# 6128                                         NaN  156646851
# 6129   {'media_keys': ['3_1740107855070441472']}  156646851
#
#                     created_at edit_history_tweet_ids  \
# 0     2023-01-03T15:18:41.000Z  [1610294585242300416]
# 1     2023-01-10T09:57:29.000Z  [1612750467859378178]
# 2     2023-01-11T10:01:06.000Z  [1613113765595320321]
# 3     2023-01-12T09:09:45.000Z  [1613463229665271809]
# 4     2023-01-13T09:41:43.000Z  [1613833662625353729]
# ...                        ...                    ...
# 6125  2023-12-13T16:03:45.000Z  [1734967350619701374]
# 6126  2023-12-19T15:32:30.000Z  [1737133815452074094]
# 6127  2023-12-20T15:13:16.000Z  [1737491360804938169]
# 6128  2023-12-22T11:16:00.000Z  [1738156427468763517]
# 6129  2023-12-27T20:31:45.000Z  [1740108226379776142]
#
#                                                entities                   id  \
# 0     {'annotations': [{'end': 6, 'normalized_text':...  1610294585242300416
# 1     {'annotations': [{'end': 2, 'normalized_text':...  1612750467859378178
# 2     {'annotations': [{'end': 51, 'normalized_text'...  1613113765595320321
# 3     {'annotations': [{'end': 19, 'normalized_text'...  1613463229665271809
# 4     {'annotations': [{'end': 7, 'normalized_text':...  1613833662625353729
# ...                                                 ...                  ...
# 6125  {'annotations': [{'end': 62, 'normalized_text'...  1734967350619701374
# 6126  {'annotations': [{'end': 61, 'normalized_text'...  1737133815452074094
# 6127  {'annotations': [{'end': 160, 'normalized_text...  1737491360804938169
# 6128  {'annotations': [{'end': 59, 'normalized_text'...  1738156427468763517
# 6129  {'annotations': [{'end': 48, 'normalized_text'...  1740108226379776142
#
#      lang                                     public_metrics  \
# 0      en  {'bookmark_count': 0, 'impression_count': 3864...
# 1      en  {'bookmark_count': 0, 'impression_count': 4887...
# 2      en  {'bookmark_count': 0, 'impression_count': 2559...
# 3      en  {'bookmark_count': 0, 'impression_count': 2087...
# 4      en  {'bookmark_count': 0, 'impression_count': 1975...
# ...   ...                                                ...
# 6125   en  {'bookmark_count': 1, 'impression_count': 2549...
# 6126   en  {'bookmark_count': 1, 'impression_count': 1905...
# 6127   en  {'bookmark_count': 1, 'impression_count': 4680...
# 6128   en  {'bookmark_count': 0, 'impression_count': 992,...
# 6129   en  {'bookmark_count': 2, 'impression_count': 6198...
#
#                                                    text      username  geo
# 0     New ABB E-mobility home charging solution help...  abbgroupnews  NaN
# 1     ABB #technology to facilitate #energyefficienc...  abbgroupnews  NaN
# 2     Better decisions for a greener data center! Ho...  abbgroupnews  NaN
# 3     ABB Formula E Season 9 goes green in Mexico!\n...  abbgroupnews  NaN
# 4     The #ABB Decoded #podcast with Frank Muehlon i...  abbgroupnews  NaN
# ...                                                 ...           ...  ...
# 6125  🌎: 2023 was the hottest year in recorded histo...        vestas  NaN
# 6126  🇪🇺: To deliver clean, affordable, and secure e...        vestas  NaN
# 6127  🌎 /🇬🇧 : In the making: one of the largest offs...        vestas  NaN
# 6128  🌎/🇬🇧: Partnering with @RWE_AG  to take the Nor...        vestas  NaN
# 6129  🇺🇸 Just in: Our largest order to date in the U...        vestas  NaN
#
# [6130 rows x 11 columns]

# %%
print(f'The number of tweets is {len(df)}')
# Out:
# The number of tweets is 6130

# %%
df = df[['username', 'lang', 'text', 'created_at']]

# %%
print(f"We have {len(df)} tweets in total, where {len(df.loc[df.lang == 'en'])} are in English language.")
# Out:
# We have 6130 tweets in total, where 5332 are in English language.

# %%
#remove qme #media links 
df = df.loc[df.lang != 'qme']
#remove zxx #used when the language is unknown
df = df.loc[df.lang != 'zxx']
#If no language classification can be made for a Tweet
df = df.loc[df.lang != 'und']
#tweets with hashtags only
df = df.loc[df.lang != 'qht']
#lang:qam for tweets with mentions only (works for tweets since 2022-06
df = df.loc[df.lang != 'qam']
#questo non so che è ma lo toglierei
df = df.loc[df.lang != 'art']

# %%
no_english = df.loc[df.lang != 'en']

# %%
print(f"We have {len(no_english)} tweets in other languages.")
# Out:
# We have 681 tweets in other languages.

# %%
print(f"We have {len(no_english.username.unique())} different companies tweeting in non-english languages:")
# Out:
# We have 17 different companies tweeting in non-english languages:

# %%
for index, row in no_english.loc[no_english.lang=='ca'].iterrows():
    print(index)
    print(row['text'])
# Out:
# 1598
# @NetflixFR Objectivement : Zenitsu ⚡️
# 4098
# #PRESS: Novo Nordisk to acquire molecule for uncontrolled hypertension from KBP Biosciences
# 4669
# @AufarAditya Major congrats ✈️

# %%
no_english.loc[1598, 'lang'] = 'fr'
no_english.loc[4098, 'lang'] = 'en' 
no_english.loc[4669, 'lang'] = 'en'
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_16276\2423589946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_english.loc[1598, 'lang'] = 'fr'
# C:\Users\valen\AppData\Local\Temp\ipykernel_16276\2423589946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_english.loc[4098, 'lang'] = 'en'
# C:\Users\valen\AppData\Local\Temp\ipykernel_16276\2423589946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_english.loc[4669, 'lang'] = 'en'

# %%
for index, row in no_english.loc[no_english.lang=='pl'].iterrows():
    print(index)
    print(row['text'])
# Out:
# 1485
# @PatrickAdemo Pikachu ⚡️
# 2561
# @ChampionsLeague Two UEFA Champions League winners 🙌

# %%
for index, row in no_english.loc[no_english.lang=='pl'].iterrows():
    no_english.loc[index, 'lang'] = 'en'
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_16276\4055858184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_english.loc[index, 'lang'] = 'en'

# %%
for index, row in no_english.loc[no_english.lang=='ar'].iterrows():
    print(index)
    print(row['text'])
# Out:
# 1909
# @shex47171391 مرحبًا ، ليس لدينا رقم Whatsapp. إذا سمحت لي بمعرفة البلد الذي تتواجد فيه ، فقد أتمكن من توفير رابط لمعلومات الاتصال الخاصة بمكتبنا المحلي ، حيث يمكنهم مناقشة مخاوفك.
#
# -Crystal
# 1914
# @shex47171391 لقد قمنا مؤخرًا بتغيير نموذج أعمالنا في العراق. من الآن فصاعدًا ، نهدف إلى توفير الأدوية واللقاحات من شركة GSK مباشرة إلى وزارة الصحة ، أو بالشراكة مع المنظمات عبر الوطنية. سوف تحتاج إلى التحدث إلى وزارة الصحة بخصوص الأدوية.

# %%
for index, row in no_english.loc[no_english.lang=='cs'].iterrows():
    print(index)
    print(row['text'])
# Out:
# 248
# We're happy to provide ČD-Telematika with ETCS Level 2 in the Czech Republic and Slovakia
#
# ▶️Learn more: https://t.co/jeNvzYeE7b
#
# #signalling #ETCS https://t.co/RMXyrZIhUA

# %%
for index, row in no_english.loc[no_english.lang=='cs'].iterrows():
    no_english.loc[index, 'lang'] = 'en'
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_16276\3971096163.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_english.loc[index, 'lang'] = 'en'

# %%
for index, row in no_english.loc[no_english.lang=='tl'].iterrows():
    print(index)
    print(row['text'])
# Out:
# 1228
# Massive thanks to all the other fantastic scientists featured in this video! Yang Huang, Xue-Fei Bai, Yang Huang, Monica Wanyi Xia, Jingyan Qu, Ivy Yuhan Li, Ann Zhu Chen, Grace Yuan Yuan, Anna Mei-Tong Lin, Daany Wenhao Li, Echo Yun Yu, and Yiming Ji 👏

# %%
for index, row in no_english.loc[no_english.lang=='tl'].iterrows():
    no_english.loc[index, 'lang'] = 'en'
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_16276\3802185037.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_english.loc[index, 'lang'] = 'en'

# %%
for index, row in no_english.loc[no_english.lang=='ht'].iterrows():
    print(index)
    print(row['text'])
# Out:
# 2565
# @ChampionsLeague Griezmann is on fire 🔥

# %%
for index, row in no_english.loc[no_english.lang=='ht'].iterrows():
    no_english.loc[index, 'lang'] = 'en'
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_16276\526034685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_english.loc[index, 'lang'] = 'en'

# %%
for index, row in no_english.loc[no_english.lang=='cy'].iterrows():
    print(index)
    print(row['text'])
# Out:
# 2609
# @Amy_rights Zero alcohol. 100% smoothness 😉

# %%
for index, row in no_english.loc[no_english.lang=='ht'].iterrows():
    no_english.loc[index, 'lang'] = 'en'

# %%
print(f"After manually cleaning the data we have {len(no_english)} tweets in languages that are not English.")
# Out:
# After manually cleaning the data we have 681 tweets in languages that are not English.

# %%
len(df.loc[df.lang=='en'])
# Out:
# 5332

# %%
5332+681
# Out:
# 6013

# %% [markdown]
# #### How many tweets for each language?

# %%
new_df = pd.concat([no_english,df.loc[df.lang=='en']])
new_df
# Out:
#      username lang                                               text  \
# 138   acciona   es  .@ACCIONAEnergia está volcada en el mayor reto...
# 139   acciona   es  Dos islas conectadas por un inmenso puente 🌉\n...
# 140   acciona   es  Ya está disponible en los canales sociales de ...
# 141   acciona   es  𝐀𝐥𝐞𝐣𝐚𝐧𝐝𝐫𝐨 𝐁𝐞𝐢𝐯𝐢𝐝𝐞, Director de Transformación ...
# 142   acciona   es  Las abejas de la ciudad recogen mucho más que ...
# ...       ...  ...                                                ...
# 6125   vestas   en  🌎: 2023 was the hottest year in recorded histo...
# 6126   vestas   en  🇪🇺: To deliver clean, affordable, and secure e...
# 6127   vestas   en  🌎 /🇬🇧 : In the making: one of the largest offs...
# 6128   vestas   en  🌎/🇬🇧: Partnering with @RWE_AG  to take the Nor...
# 6129   vestas   en  🇺🇸 Just in: Our largest order to date in the U...
#
#                     created_at
# 138   2023-11-11T11:30:00.000Z
# 139   2023-11-12T11:00:00.000Z
# 140   2023-11-14T14:03:22.000Z
# 141   2023-11-14T16:21:46.000Z
# 142   2023-11-14T21:00:01.000Z
# ...                        ...
# 6125  2023-12-13T16:03:45.000Z
# 6126  2023-12-19T15:32:30.000Z
# 6127  2023-12-20T15:13:16.000Z
# 6128  2023-12-22T11:16:00.000Z
# 6129  2023-12-27T20:31:45.000Z
#
# [6013 rows x 4 columns]

# %%
len(new_df)
# Out:
# 6013

# %% [markdown]
# #### Translate non-english texts

# %%
# !pip install translate
# !pip install googletrans==3.1.0-alpha
# Out:
# Requirement already satisfied: translate in c:\users\valen\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: click in c:\users\valen\anaconda3\lib\site-packages (from translate) (8.0.4)
# Requirement already satisfied: lxml in c:\users\valen\anaconda3\lib\site-packages (from translate) (4.9.3)
# Requirement already satisfied: requests in c:\users\valen\anaconda3\lib\site-packages (from translate) (2.31.0)
# Requirement already satisfied: libretranslatepy==2.1.1 in c:\users\valen\anaconda3\lib\site-packages (from translate) (2.1.1)
# Requirement already satisfied: colorama in c:\users\valen\anaconda3\lib\site-packages (from click->translate) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\valen\anaconda3\lib\site-packages (from requests->translate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\valen\anaconda3\lib\site-packages (from requests->translate) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\valen\anaconda3\lib\site-packages (from requests->translate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valen\anaconda3\lib\site-packages (from requests->translate) (2023.7.22)
# Requirement already satisfied: googletrans==3.1.0-alpha in c:\users\valen\anaconda3\lib\site-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in c:\users\valen\anaconda3\lib\site-packages (from googletrans==3.1.0-alpha) (0.13.3)
# Requirement already satisfied: certifi in c:\users\valen\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0-alpha) (2023.7.22)
# Requirement already satisfied: hstspreload in c:\users\valen\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0-alpha) (2024.5.1)
# Requirement already satisfied: sniffio in c:\users\valen\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0-alpha) (1.2.0)
# Requirement already satisfied: chardet==3.* in c:\users\valen\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0-alpha) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\valen\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0-alpha) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\valen\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0-alpha) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\valen\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0-alpha) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\valen\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0-alpha) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\valen\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0-alpha) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\valen\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0-alpha) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\valen\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0-alpha) (3.0.0)

# %%
from translate import Translator
from tqdm.notebook import tqdm
from googletrans import Translator

translator = Translator()

# %% [markdown]
# For now I am using google translate because is free and has no limit, maybe I can try deepl but for now i just found an api with a small free translation rate per day

# %%
english_texts = []
for index, row in tqdm(no_english.iterrows(), total=len(no_english)):
    print(f'row index is {index}')
    translated = translator.translate(row['text'], src=row['lang'], dest="en").text
    print(f'translated text is: {translated}')
    english_texts.append(translated)
    print(f'number of translated text is: {len(english_texts)}')
# Out:
#   0%|          | 0/681 [00:00<?, ?it/s]
# row index is 138
# translated text is: .@ACCIONAEnergia is focused on the greatest photovoltaic challenge developed in its 30 years of life in the renewable sector: building 🇺🇸 solar plants with a combined power equivalent to a nuclear power plant, with more than two million panels 👇https://t .co/HPfeti7ABI
# number of translated text is: 1
# row index is 139
# translated text is: Two islands connected by a huge bridge 🌉
#
# But not just any one: 2.5 km long with a 650 m cable-stayed main structure. We are talking about the Cebu cable-stayed bridge, one of our largest engineering works in Southeast Asia 👇
#
# https://t.co/CQywj6hV2g https://t.co/Yfv7RU8rfQ
# number of translated text is: 2
# row index is 140
# translated text is: Episode 2 of the docuseries '#LaLuzQuePermanece' is now available on the social channels of @acciona_org. Don't miss the mysteries of the Amazon jungle and the commitment of the Copal Urco community to renewable energies 👇 https://t.co/Fmpu2s8bxi
# number of translated text is: 3
# row index is 141
# translated text is: 𝐀𝐥𝐞𝐣𝐚𝐧𝐝𝐫𝐨 𝐁𝐞𝐢𝐯𝐢𝐝𝐞, Director of Digital Infrastructure Transformation, will be present tomorrow, Wednesday, November 15, at 9:00 am, in Cantabria 🇪🇸 giving a presentation on Industrial Connectivity 📅📢 Don't miss it!
#
# All the details here ⤵
# number of translated text is: 4
# row index is 142
# translated text is: City bees collect much more than pollen
#
# 🐝🐝🐝
#
# These pollinators trap samples of bacteria and microbes that allow us to know the state of health of the environment 🏙️⚕️ Find out how they do it 👇 https://t.co/DoBjqNi6Dk
# number of translated text is: 5
# row index is 143
# translated text is: @CarlosaUruetav Here are some of them https://t.co/UyTN84UKiP and https://t.co/XKJe3SPKDQ Greetings!
# number of translated text is: 6
# row index is 145
# translated text is: 📅 Tomorrow, Manuel Navarro, Director of Water for Agriculture, participates in the @Tecniberia Conference, sharing his experience in Session II, Water Table ''𝐀𝐠𝐫𝐢𝐜𝐮𝐥𝐭𝐮𝐫𝐚, 𝐫𝐠𝐢́𝐚'', along with other professionals in the sector 🗣️
#
# 💦 More information here:
# number of translated text is: 7
# row index is 146
# translated text is: We have built more than 5,000 km of highways, highways and roads in recent years around the world: Australia, Spain, Canada, Denmark....🌏🛣️ A world map of increasingly innovative and sustainable smart roads 👉 https:// t.co/lYFJ8wo0PV https://t.co/UEd6g7JNsh
# number of translated text is: 8
# row index is 147
# translated text is: Good news for the wind sector! The project combines our experience in the use of composite materials, @ACCIONAEnergia's access to disused wind turbine blades and @renercycle's activities in the dismantling of wind turbines
# https://t.co/1xNBfSZ1Nv
# number of translated text is: 9
# row index is 148
# translated text is: The @ACCIONA_ORG foundation extends its renewable and affordable supply service and already benefits more than 1,600 people in the province of Coquimbo
#
# 🇨🇱🇨🇱🇨🇱
#
# https://t.co/TWAljGdc5u
# number of translated text is: 10
# row index is 149
# translated text is: Ultrasounds to the rescue 🦹‍♀️🦸‍♂️
#
# According to the latest research, chemical residues that accumulate in groundwater and wastewater 💦 could be cleaned using ultrasound 👇 https://t.co/LS8FLUW6Dw
# number of translated text is: 11
# row index is 150
# translated text is: This system will calculate the Water footprint in the @COE_es facilities, promote the reduction of water consumption and replicate the model in other sports organizations 👇💦
#
# https://t.co/IbtKG9tb5I
# number of translated text is: 12
# row index is 151
# translated text is: The main challenge is to develop correct water management based on climate adaptation and mitigation. We take on the challenge of extending a positive water footprint through the design of regenerative water infrastructure
# https://t.co/IbtKG9tIVg
# number of translated text is: 13
# row index is 152
# translated text is: What is reverse osmosis desalination? 💦
#
# It is the most widespread and advanced desalination system in the world 🌏 Its implementation represents more than 60% compared to the rest of the methods 👇 https://t.co/lKRjLHUL4U
# number of translated text is: 14
# row index is 153
# translated text is: .@ACCIONAEnergia is simultaneously constructing four photovoltaic projects in 🇺🇸 that add up to 1.3 GWp of peak power. The new facilities will generate clean energy equivalent to the consumption of more than 210,000 American homes 🏡 https://t.co/I0f7Jm69CB
# number of translated text is: 15
# row index is 154
# translated text is: .@ACCIONA_ORG, together with @AECID_es and @ayalafoundation, deploys access to clean electricity from home photovoltaic systems to areas of the province of Palawan (Philippines) without connection to the conventional electrical grid 💡🇵🇭
# number of translated text is: 16
# row index is 155
# translated text is: ⚡️Renewable energies ⚡️
#
# Why are they key to combating 𝗰𝗿𝗶𝘀𝗶𝘀 𝗰𝗹𝗶𝗺𝗮́𝘁𝗶𝗰𝗮 🌡️ and what are their benefits 👇
# number of translated text is: 17
# row index is 156
# translated text is: @Robertolui8995 Thank you very much and also!
# number of translated text is: 18
# row index is 157
# translated text is: 📅 This Friday, November 24, our colleague Miguel Ángel París, from the Construction Technology Center, participates in the CONSTRUYES congress, debating the future of construction, with a focus on hydrogen and electrification ✅
#
# All the info ⬇
# number of translated text is: 19
# row index is 158
# translated text is: Good news! We have begun excavations for the #construction of the second phase of the Western Harbor Tunnel in Australia 🚇🇦🇺
#
# All the details 👇
# number of translated text is: 20
# row index is 159
# translated text is: Have you ever thought of the city as nature? 🌆🌳
#
# A new perspective for the urban future through biourbanism ⤵️ https://t.co/uBHBMneIjn
# number of translated text is: 21
# row index is 160
# translated text is: 4 decades developing desalination projects that bring a key asset for life to more than 30 million. of people, most of them residents on islands around the 🌎 and in areas threatened by water stress 🏝️
#
# This is how we do it ⤵️ https://t.co/6fYCQ9qYtV https://t.co/mPhxG3oelz
# number of translated text is: 22
# row index is 161
# translated text is: The rehabilitation project of the emblematic Canfranc Station (Huesca) 🇪🇸 has been awarded three important recognitions 🚉🏅
#
# Know the details ⤵
# number of translated text is: 23
# row index is 162
# translated text is: We incorporated a new #energystorage system for energy in the construction of the Alentejo hospital in Portugal 🏗🏥🇵🇹
#
# Know the details 👇
# number of translated text is: 24
# row index is 163
# translated text is: The coexistence of renewable energy ⚡️with agricultural practices 🧑‍🌾🚜 has led to the birth of the 𝗲𝗻𝗲𝗿𝗴𝗶́𝗮 𝗮, which promises to revolutionize sustainable crops of the 21st century ⤵️ https://t.co/uUljA6INhw
# number of translated text is: 25
# row index is 164
# translated text is: The @AccionaSainz of our drivers @LaiaSanz_ & @mattiasekstroem concludes in one week a new season of @ExtremeELive E, this time in the #CooperXPrix test in Antofagasta 🇨🇱 with the possibility of becoming champion for the first time 🏆
#
#  #DrivenByNature https://t.co/RiezO8wOzT
# number of translated text is: 26
# row index is 165
# translated text is: .@ACCIONAEnergia deploys two #BladeLifters to transport blades to the MacIntyre wind farm. These vehicles are the first of their kind used in Australia and will increase the pace of on-site shovel delivery and reduce the environmental footprint of the project 🌬️☀️ https://t.co/kYxJCMNEqN
# number of translated text is: 27
# row index is 166
# translated text is: Flying over an impressive pumping station in Spain 💦🇪🇸 https://t.co/Xwq9oitrMy
# number of translated text is: 28
# row index is 167
# translated text is: 🔴🗣️ Aina Soler, Project Manager, participates this Wednesday at 10:05 a.m. in the Young Water Hack, organized by the IWA, speaking in the presentation “From waste to resource: the paradigm shift in wastewater treatment” 💦
#
# 🔗 All the details here:
# number of translated text is: 29
# row index is 168
# translated text is: News that we love to share: @ACCIONAEnergia revalidates its status as the greenest electricity company in the world for the ninth consecutive year according to the "Top 100 Green Utilities" ranking prepared by @energyintel, an independent consultancy specialized in energy markets 🥳🎈
# number of translated text is: 30
# row index is 169
# translated text is: A new generation of garments arrives that contract depending on the temperature and insulate better from the cold, among other functions 🤯
#
# Smart fabrics 👕🧠 https://t.co/9DFYxDHsmf
# number of translated text is: 31
# row index is 170
# translated text is: Our Foundation @ACCIONA_ORG premieres a new episode of the documentary series '#LaLuzQuePermanece' on YouTube. Do not miss it! https://t.co/Yk1GAeGoob
# number of translated text is: 32
# row index is 171
# translated text is: 📢 Coinciding with our 25th anniversary in Portugal, we attended the ENEG 2023 meeting, organized by the APDA, where we have a stand to publicize our solutions and establish a meeting area with professionals from the sector
#
# Know the details ⤵
# number of translated text is: 33
# row index is 172
# translated text is: We boost the #renewable supply of Mostostal Warszawa, our subsidiary in Poland 🇵🇱, with our #decarbonization fund ✅
# All the info 👇
# number of translated text is: 34
# row index is 173
# translated text is: 🗣️ Paula Pérez, Digital Transformation Manager, will give a presentation tomorrow on “Water Positive: Water-Energy Nexus through desalination and reuse” 💦
#
# 📅 3:45 p.m.
# 📍 CETA – CEDEX (Madrid)
#
# More info 👇
# number of translated text is: 35
# row index is 174
# translated text is: We introduce bioclimatic and bioconstruction technologies in the new complex of the Xunta de Galicia (Spain) 🇪🇸
#
# These systems represent an important #innovation in terms of #construction and #engineering thanks to the use of natural resources 🚧✅
# number of translated text is: 36
# row index is 175
# translated text is: The Pajares variant of the Madrid-Asturias High Speed ​​Line has been inaugurated 🇪🇸🚇
#
# The waterproofing of tunnels using a coating system based on composite materials has received international awards 🙌
#
# Discover the news ⤵
# number of translated text is: 37
# row index is 176
# translated text is: The #COP28UAE begins, the climate summit to fulfill the Paris Agreement 🌡️To mitigate climate change, coal, oil and gas production must decrease rapidly, and global renewable energy production must triple by 2030 📈 https:// t.co/jIidN198Xl
# number of translated text is: 38
# row index is 178
# translated text is: Wind turbines take away space from agriculture and livestock --> ✖️ FALSE ✖️
# The surface area occupied by a wind turbine is minimal. In fact, wind farms are perfectly compatible with agricultural and livestock activities that take place in that same space 🌬️🐏
# number of translated text is: 39
# row index is 180
# translated text is: One of the main keys when working with tunnel boring machines is choosing and adapting the right machine for each terrain. To face these challenges, we have several types of tunnel boring machines: open Main Beam type, single shield, double shield, etc. 🚇⤵️ https://t.co/ayhyTVjhYB
# number of translated text is: 40
# row index is 181
# translated text is: “Civil society should not wait for regulation, but lead the transition”
#
# Our president and CEO, José Manuel Entrecanales, participates in # COP28UAE, where he sends a clear message to increase climate action 💪🌎
#
# #ACCIONACOP28 https://t.co/WpUt0wRoQU
# number of translated text is: 41
# row index is 182
# translated text is: On the 30th, we received the Spain-Italy Chamber of Commerce Award in its seventeenth edition🏆
#
# This award is awarded annually by the Spanish Chamber of Commerce in Italy to companies that stand out for their innovation and sustainable management of water infrastructure💧
# number of translated text is: 42
# row index is 183
# translated text is: The largest female expedition to Antarctica, organized by @HomewardBound16 and ACCIONA, has just concluded after a journey in which 188 women have contemplated the effects of climate change.
#
# And what better way to end it than with this message from Jane Goodall 👇 https://t.co/dDwjowD5mp
# number of translated text is: 43
# row index is 184
# translated text is: We had it in our hands, but it couldn't be. We are proud of the work of all the members of @AccionaSainz ❤️
#
# Thank you for this year @LaiaSanz_, @mattiasekstroem, @CSainz_oficial #DrivenByNature
#
# ➕info: https://t.co/sZHrkMeEli https://t.co/wdfpXTFVDO
# number of translated text is: 44
# row index is 185
# translated text is: Great news! Ecuador inaugurates Line 1 of the Quito Metro 🇪🇨
#
# The inauguration and entry into operation of the line constitutes the first element of a new public transport system in the city 🚇
#
# All the info ⤵
# number of translated text is: 45
# row index is 186
# translated text is: Good news from Australia! 🇦🇺⤵️
#
# The project will increase renewable energy that can be delivered through the national electricity grid, helping Australia transition to a low emissions future 👏⚡️
#
# https://t.co/MWcOZ5s5GR
# number of translated text is: 46
# row index is 188
# translated text is: A plant capable of generating 1.5 MW of renewable energy could be one of the first demonstrations of the potential of thermal gradient energy ⚡️🌊
#
# 👇Ocean thermal energy 👇
# https://t.co/LqTNMJ2wai
# number of translated text is: 47
# row index is 189
# translated text is: EPISODE 1 #ACCIONACOP28 | We start our coverage of @COP28_UAE with @tv_Amaro ⤵️
#
# A world of contrasts, but a path towards regeneration 🌎 Discover the perfect example 📺👇
#
# https://t.co/VtmRVU6WoR
# number of translated text is: 48
# row index is 190
# translated text is: 📢 Discover all the #news that our company has experienced during the month of November 2023 📺 #ACCIONAin1min
# number of translated text is: 49
# row index is 191
# translated text is: What just a few years ago seemed like a utopia is today a reality. We are already printing 𝐦𝐨𝐛𝐢𝐥𝐢𝐚𝐫𝐢𝐨 𝐮𝐫𝐛𝐚𝐧𝐨 𝐞𝐧 𝟑𝐃 for the homes we build and exploring a near future where buildings are 100% net zero 🏗️ 🏙️ We tell you about this progress 👇
# number of translated text is: 50
# row index is 192
# translated text is: The energy transition is already saving more than 200,000 lives a year thanks to the reduction in the use of coal and pollutants in the air 🌫️👏
#
# A study confirms this 👇 #COP28UAE
# https://t.co/3N6jqNenNz
# number of translated text is: 51
# row index is 193
# translated text is: EPISODE 2 #ACCIONACOP28 | In episode 2 of our trip to @COP28_UAE, we move among sands that, little by little, are swallowing the roads that surround Dubai 🇦🇪🐫
#
# A global alarm signal ♨️
#
# #COP28 | @tv_Amaro https://t.co/wq9Mrhvmi6
# number of translated text is: 52
# row index is 194
# translated text is: @COP28_UAE @tv_Amaro EPISODE 2 #ACCIONACOP28 | Every year around 12 million hectares are lost to desertification, 2,000 soccer fields per hour. A consequence of climate change and unsustainable use of soils ♨️🥴
#
# #COP28 | @tv_Amaro https://t.co/wq9Mrhvmi6
# number of translated text is: 53
# row index is 195
# translated text is: @COP28_UAE @tv_Amaro EPISODE 2 #ACCIONACOP28 | However, there are measures and technologies to combat this problem. We visited the largest vertical garden on the planet, also located in the UAE, which promotes a regenerative agriculture model
# 🥬🥬👩‍🔬🧑‍🔬
#
# #COP28 | @tv_Amaro https://t.co/wq9Mrhvmi6
# number of translated text is: 54
# row index is 196
# translated text is: Green hydrogen: why it is on the right track to be the fuel of the future 🟢 👇 https://t.co/jWU2zZ8QMh
# number of translated text is: 55
# row index is 197
# translated text is: Water or nacelle? 💧⚡️ Can you guess what surface these views are reflected on? 👀
#
# (Video recorded by Iñaki Antoñana, O&M technician of the #ACCIONAteam. Thank you, Iñaki!)
#
# #ClimateGramers https://t.co/52gjkDuRSE
# number of translated text is: 56
# row index is 198
# translated text is: @pablovinueza2 Thank you very much for your message! #ACCIONAteam
# number of translated text is: 57
# row index is 199
# translated text is: @elmanyana Hello Eloy! We want to contact you by DM to present you with an initiative that we think might be of interest to you, but it doesn't allow us to send you a message by not following us back. Are you interested? We look forward. Thank you so much!
# number of translated text is: 58
# row index is 200
# translated text is: @PedroFresco Hello Pedro! We want to contact you by DM to present you with an initiative that we think might be of interest to you, but it doesn't allow us to send you a message by not following us back. Are you interested? We look forward. Thank you so much!
# number of translated text is: 59
# row index is 201
# translated text is: We're proud to support the @HomewardBound16 program and the incredible scientists within it who are redefining the narrative of global leadership 👩‍🔬👷‍♀️This year's trip to Antarctica is over, but as @FabianDattner says: "This is just the end of the beginning" https://t.co/Bdk1Xb8B7M
# number of translated text is: 60
# row index is 202
# translated text is: We are approaching the end of the journey of '#LaLuzQuePermanece' jumping from the jungle to the Andean mountains. Don't miss episode 4 here
#
# 📺👇 https://t.co/TdWvdNHdH2
# number of translated text is: 61
# row index is 203
# translated text is: Great news! The Victorian Government has selected us to carry out the first batch of tunnels for the Suburban Rail Loop East project, in Melbourne 🇦🇺 within the Suburban Connect consortium, together with CPB Contractors and @GhellaSpa 🚇
# https://t.co/d4LUwxOCzI
# number of translated text is: 62
# row index is 204
# translated text is: 📅 This Thursday, our colleague Ana Garcia, Responsible for the Sustainability Report of the Water area, participates in the sustainability sessions of @CatalanWaterP “Reporting sustainability to the Water sector” 💧🗣️
#
# Find out the details and sign up ⤵
# number of translated text is: 63
# row index is 205
# translated text is: Have you ever wondered what makes everything spin steadily and precisely? 🔄
#
# Discover the wonderful force that drives the world and our essential role in The Planet Cycle 🌎✨
#
# Happy Holidays! #ThePlanetCycle
# number of translated text is: 64
# row index is 206
# translated text is: Recently, Ecuador inaugurated Line 1 of the @MetrodeQuito. A milestone in the country's sustainable mobility and in the transition towards a net-zero city model to which we are proud to have contributed. Discover the project here 🚇👇
#
# https://t.co/GPcWxZU5Vt
# number of translated text is: 65
# row index is 207
# translated text is: After two weeks of intense negotiations, #COP28 ends with a milestone: the express mention of leaving fossil fuels behind 🏭👋
#
# #COP28UAE @COP28_UAE
#
# https://t.co/zV7gfaDAzS
# number of translated text is: 66
# row index is 208
# translated text is: Another point that remains is the need to continue promoting renewable energies. A decision that is based on the report published in October by the International Energy Agency (@IEA)
#
# #COP28UAE @COP28_UAE
#
# https://t.co/zV7gfaDAzS
# number of translated text is: 67
# row index is 209
# translated text is: @IEA @COP28_UAE In six years, renewables should account for 77% of the total installed capacity, and 68% of that generated ⚡️📈
#
# #COP28UAE #COP28 @COP28_UAE
# https://t.co/zV7gfaDAzS
# number of translated text is: 68
# row index is 210
# translated text is: Despite being only 6% of the population, they take care of 80% of the world's biodiversity ⛰️🫏🌴
#
# We talk about the wisdom of indigenous peoples 👇https://t.co/txzhKhIbFU
# number of translated text is: 69
# row index is 211
# translated text is: @quetzalenergia @elgansospain Thank you very much! https://t.co/mC6lAPqShV
# number of translated text is: 70
# row index is 212
# translated text is: We began the expansion works of the Granada Metro (Spain), which represents an extension of 2.7 kilometers and the construction of four new stations 🚇🏗
#
# More info 👇
# number of translated text is: 71
# row index is 213
# translated text is: We are very proud of all the people from the #ACCIONAteam of @ACCIONAEnergia who have made it possible ❤️
#
# The Aldoga PV (380 MW), in Australia, will create up to 350 jobs during its construction and will generate clean electricity to supply almost 185,000 homes 🏠 https://t.co/jik163dFnL
# number of translated text is: 72
# row index is 214
# translated text is: Have you ever wondered what makes everything spin steadily and precisely? 🔄
#
# Discover the wonderful force that drives the world and our essential role in The Planet Cycle 🌎✨
#
# Happy Holidays! #ThePlanetCycle
# number of translated text is: 73
# row index is 215
# translated text is: They are the first shoes in the world made with recycled wind blades ♻️👟
#
# We teamed up with @elgansospain to launch a line of sneakers whose manufacturing used a 23-meter-long blade from the Aibar wind farm in Navarra 🌬️ https://t.co/n2hQND3JQr
# number of translated text is: 74
# row index is 216
# translated text is: Have you ever wondered what makes everything spin steadily and precisely? 🔄
#
# Discover the wonderful force that drives the world and our essential role in The Planet Cycle 🌎✨
#
# Happy Holidays! #ThePlanetCycle
# number of translated text is: 75
# row index is 217
# translated text is: The project will remove 19,000 vehicles a day from the Greensborough road and will include the planting of 4,000 trees 🇦🇺🛣️🌳🌳🌳
#
# https://t.co/dSNnuD0VlW
# number of translated text is: 76
# row index is 218
# translated text is: @COP28_UAE @tv_Amaro EPISODE 3 #ACCIONACOP28 | We conclude our trip to Dubai with the main conclusions of the #COP28UAE and interviews with our president José Manuel Entrecanales, @PEspinosaC and @marcelomena 🌎🫶
#
# #COP28 | @tv_Amaro https://t.co/M9EW4TiS4l
# number of translated text is: 77
# row index is 219
# translated text is: Now that we end the year and the holidays are approaching, this evocative metaphor with hand-drawn illustrations invites us to reflect on our coexistence with life and the Earth 🌎✨ #ElCiclodelPlaneta
#
# Share so the cycle continues: https://t.co/fHAKM2RjJ2 https://t.co/WZWc3lBqkJ
# number of translated text is: 78
# row index is 220
# translated text is: 𝐄𝐱𝐨𝐞𝐬𝐪𝐮𝐞𝐥𝐞𝐭𝐨 🦿
#
# People with hemiplegia who walk again or construction workers who lift 90 kilos effortlessly are some applications of this technology ⤵️ https://t.co/6C8reaz4kE
# number of translated text is: 79
# row index is 221
# translated text is: Good news! @AimRoads, our subsidiary in Canada dedicated to infrastructure maintenance, has been awarded for safety and health in infrastructure maintenance 👷🏆
#
# More details ⤵
# number of translated text is: 80
# row index is 222
# translated text is: We are very happy to tell you that we are going to develop one of the largest renewable energy networks in Australia 🇦🇺 The new infrastructure will mobilize an investment of €6.2 billion and will generate 5,000 jobs during its construction 😍👇
#
# https://t.co/A2pqQAhbkg
# number of translated text is: 81
# row index is 223
# translated text is: The dam, whose construction was completed in September, is 60 meters high and more than a kilometer long at the crest 🇨🇦
#
# https://t.co/KXEIJ29daT
# number of translated text is: 82
# row index is 224
# translated text is: Innovation and renewable energies ⚡️could be key to tackling Madagascar's emergency food state 🇲🇬 Find out how ⤵️
# https://t.co/37lhkj681R
# number of translated text is: 83
# row index is 225
# translated text is: A century after its construction, the Seira Hydroelectric Power Plant, in Spain 🇪🇸, continues to produce clean energy, while the beauty of its architecture and the machinery it houses inside are a true joy for the senses 👇 https:// t.co/S5WfkPI64M
# number of translated text is: 84
# row index is 226
# translated text is: There is a different way of doing business that seeks to lead climate action to make a healthier, safer and more prosperous planet possible for everyone🌎🫶
#
# Our #ACCIONAteam works this way to achieve it 😍👇
# number of translated text is: 85
# row index is 227
# translated text is: @revenergetica Thanks Xavier! We hope you like them ⚡❤️ @ACCIONAEnergia
# number of translated text is: 86
# row index is 228
# translated text is: @Sergio_FerMun @elgansospain Thank you Sergio! ⚡❤️
# number of translated text is: 87
# row index is 229
# translated text is: This year we celebrate the holidays with #ElCiclodelPlaneta, a piece with which we share the desire that unites all the people who make up ACCIONA: to continue working day after day for a more prosperous future for our planet 🌎
#
# Share the congratulations here 👇
# number of translated text is: 88
# row index is 230
# translated text is: ▶ Discover all the news that our company has experienced during the month of December 2023 👀 | #ACCIONAin1min
# number of translated text is: 89
# row index is 231
# translated text is: The 𝗿𝗲𝗴𝗲𝗻𝗲𝗿𝗮𝗰𝗶𝗼́𝗻 is a commitment to the reconciliation of humans with nature and the restoration of its balance 🌳👨‍👩‍👧‍👧
#
# One step beyond the sustainability that we tell you in detail here 👇
# number of translated text is: 90
# row index is 232
# translated text is: We end the year with a piece to congratulate the holidays and to share the wish that unites all the people who make up ACCIONA: to continue working day after day for a more prosperous future for our planet 🌏✨🤝
#
# Share the congratulations 👇 #ElCicloDelPlaneta
# number of translated text is: 91
# row index is 240
# translated text is: @cecile_texier We tend to agree Cécile :)
# number of translated text is: 92
# row index is 248
# translated text is: We're happy to provide ČD-Telematika with ETCS Level 2 in the Czech Republic and Slovakia
#
# ▶️Learn more: https://t.co/jeNvzYeE7b
#
# #signalling #ETCS https://t.co/RMXyrZIhUA
# number of translated text is: 93
# row index is 306
# translated text is: @BB27000 🚂always, BB! 😉
# number of translated text is: 94
# row index is 490
# translated text is: @tgvdu45 @SNCFNumerique Wohoo! See you soon Theo! No need to test our simulator I think? 😁
# number of translated text is: 95
# row index is 492
# translated text is: You are always welcome dear Théo!
# #TeamAlstom #VivaTech https://t.co/LEBpIsqP3Z
# number of translated text is: 96
# row index is 818
# translated text is: Game on, 2023! We are pleased to announce that Danfoss extends global sponsorship for Danish sports club #SønderjyskE. SønderjyskE has brought home victories for South Jutland with @SEishockey @SEherrehbold and SønderjyskE Damehandbold. Read more: https://t.co/RWSkiipNP5 https://t.co/DGJvY0CMrw
# number of translated text is: 97
# row index is 966
# translated text is: “We are proud to be able to count on a group like Danone and its teams who choose France and innovation. You are synonymous with excellence and employment.” — Élisabeth Borne, French Prime Minister
# number of translated text is: 98
# row index is 967
# translated text is: “If I am here today it is because the projects you are carrying out contribute to building the France of tomorrow. So we will continue to support you. You represent the future of our food.” — Élisabeth Borne, French Prime Minister
# number of translated text is: 99
# row index is 968
# translated text is: "The Saclay center is the future of health through food. I am happy that you have chosen to set up here, this center shows the excellence and rigor of French research. We have confidence in you." – Élisabeth Borne, French Prime Minister
# number of translated text is: 100
# row index is 986
# translated text is: @remitouja Hello Rémi, and yet this change of colors is important. Colored bottles are more difficult to recycle, going through specialized recycling channels and being necessarily intended for uses other than food. (1/2)
# number of translated text is: 101
# row index is 987
# translated text is: @remitouja With these new transparent plastic models they can be recycled for food use, therefore allowing better "recyclability". (2/2)
# number of translated text is: 102
# row index is 993
# translated text is: SURPRISE INTERVIEW 📚
#
# Clarisse Agbégnénou (@Gnougnou25) and @SoldeTyphaine, our @Danone champions found themselves “On the board!!!”
# In front of the children, the athletes answered all their questions without taboo!
#
# #ChampionsATousLesAges
# @autableoff
# number of translated text is: 103
# row index is 995
# translated text is: A look back at a special day... This April 6, on the occasion of Olympic and Paralympic Week (SOP), our Danone Champions brightened up the morning of the children of a school in @villedesuresnes.
# @Paris2024 #SOP2023 #ChampionsATousLesAges https://t.co/nsbJ0TC4Aj
# number of translated text is: 104
# row index is 996
# translated text is: Olympic and Paralympic Week has been part of the @education_gouv ministry's program since 2017. The opportunity to discuss access and inclusion in sport, major health issues. As an official partner of @Paris2024, Danone supports this initiative https://t.co/wBtppvN6hv
# number of translated text is: 105
# row index is 997
# translated text is: Olympic and Paralympic Week is also a great opportunity to promote “moving well and eating well”, from a very young age and at all stages of life! #ChampionsAtouslesAges #SOP2023 @Paris2024 https://t.co/ygl6Tp4WAo
# number of translated text is: 106
# row index is 998
# translated text is: The opportunity for Danone champions to return to school, to meet the champions of tomorrow! @sofyanemehiaoui @JKR_17 @SoldeTyphaine @ZhoyaSasha @SMartinetJudo @Paris2024 #SOP2023 #ChampionsAtouslesAges https://t.co/Tp3bD64fPm
# number of translated text is: 107
# row index is 1012
# translated text is: “Have anyone ever told you that you suck?”
# Clarisse Agbégnénou be like: become world champion for the sixth consecutive time.
# We have the answer to the question 😉
# BRAVO @Gnougnou25🏆 Danone is so proud to support you!
# #ChampionsATousLesAges https://t.co/Xijd5UOZHx
# number of translated text is: 108
# row index is 1013
# translated text is: Weak point: too strong.
# @Gnougnou25 six times world champion.
# 🥇🥇🥇🥇🥇🥇
# We still can't get over it 🤩
# #ChampionsATousLesAges https://t.co/i7jF3NuULC
# number of translated text is: 109
# row index is 1022
# translated text is: #OlympicDay #LetsMove!
# Who better than our champions @JKR_17 and Melvyn Richardson, members of the #DanoneChampions Team to make everyone want to move🤸
# So let's move as often as possible with colleagues, family or friends! #ChampionsDanone https://t.co/lgsZincahw
# number of translated text is: 110
# row index is 1030
# translated text is: The @Paris2024 Olympic Games are exactly 1 year away! On this occasion, discover our team of #ChampionsDanone ⤵️
# We start with @Gnougnou25 🥋
# J-3626: First world title
# J-365: Ready to be on top of the world!
# https://t.co/nlTizzlA1a
# number of translated text is: 111
# row index is 1031
# translated text is: We continue with @SoldeTyphaine
# J-1387: First national selection
# J-399: A crucial objective
# https://t.co/ZkSm9bFfLB
# number of translated text is: 112
# row index is 1032
# translated text is: It’s @JKR_17’s turn🤾‍♂️
# J-4006: In full preparation
# J-365: Ready to give voice
# https://t.co/x3CranXCuY
# number of translated text is: 113
# row index is 1033
# translated text is: Without forgetting @FERRANDPREVOT 🚴‍♀️
# J-3960: Team time trial champion
# J-365: A golden opportunity in mountain biking
# https://t.co/j6lqztxk3m
# number of translated text is: 114
# row index is 1034
# translated text is: And of course @ZhoyaSasha🏃‍♂️
# J-922: The beginning of the story on the web
# D-365: Ready to reach for the stars
# https://t.co/cYOe83RAq4
# number of translated text is: 115
# row index is 1035
# translated text is: Here is now @sofyanemehiaoui 🏀
# J-4101: Heading to a European final
# J-399: Destination the ultimate competition
# https://t.co/yNsXl3fXml
# number of translated text is: 116
# row index is 1036
# translated text is: After Richardson father, we ask for the son!
# J-3263: Succession is assured
# D-365: The medal is hoped for
# https://t.co/M5bi27XoI1
# number of translated text is: 117
# row index is 1037
# translated text is: And finally, Sandrine Martinet-Aurières 🥋
# D-1065: It was not the end in Tokyo
# D-399: We continue until Paris 2024
# https://t.co/dSIR4HNkvy
# number of translated text is: 118
# row index is 1038
# translated text is: D-365 before @Paris2024🤸‍♂️
# The #ChampionsDanone team takes to the track ✨ For the occasion, from 1500 likes on this tweet we will give you 12 prizes of 2 places to attend the competitions. To participate: like this tweet and subscribe to the @Danone account. Good luck 🍀 https://t.co/kQ8SHpiWBA
# number of translated text is: 119
# row index is 1039
# translated text is: We will be there in 365 days to cheer on Clarisse in the stands of the Paris 2024 Olympic Games! You too, support the athletes of the #ChampionsDanone collective
# #1YearToGo https://t.co/ILtchnvu1h
# number of translated text is: 120
# row index is 1042
# translated text is: 14th world title for our champion Pauline @FERRANDPREVOT 🚵‍♀️
# Yes you read correctly: 14TH WORLD TITLE🤩
# Bravo Pauline, we are so proud to accompany you!
#
# #ChampionsATousLesAges https://t.co/uBeOkjXWEy
# number of translated text is: 121
# row index is 1043
# translated text is: She's just too strong...
#
# Bravo Pauline @FERRANDPREVOT for this new demonstration and this 15th global title! 🇫🇷🚵🏻‍♀️ #Championatouslesages https://t.co/ewSgtDczZE
# number of translated text is: 122
# row index is 1050
# translated text is: Sport, champions, meetings, emotion on the program for Paralympic Day @Paris2024. A preview of the “return match” in Paris in 2024! Thank you to the visitors and our #TeamChampionsDanone @sofyanemehiaoui, Sandrine Martinet, @SoldeTyphaine, @ZhoyaSasha 🙌
# number of translated text is: 123
# row index is 1051
# translated text is: We vibrated with you during Para' Day🤸
# Relive the highlights before the return match in a few months!
# @paris2024
# #ChampionsATousLesAges https://t.co/qRuyAoZJPm
# number of translated text is: 124
# row index is 1064
# translated text is: Alongside @CarrefourFrance and @Paris2024, we support healthy eating and physical activity for all! With the “Sports Clubs Program”, 100,000 products will be offered for snacks to licensees of 5 amateur clubs 💪
# #ChampionsAtousLesAges #Paris2024 https://t.co/MayPHpUXmx
# number of translated text is: 125
# row index is 1228
# translated text is: Massive thanks to all the other fantastic scientists featured in this video! Yang Huang, Xue-Fei Bai, Yang Huang, Monica Wanyi Xia, Jingyan Qu, Ivy Yuhan Li, Ann Zhu Chen, Grace Yuan Yuan, Anna Mei-Tong Lin, Daany Wenhao Li, Echo Yun Yu, and Yiming Ji 👏
# number of translated text is: 126
# row index is 1394
# translated text is: We are waiting for you at #SIBCA2023. Come meet us (A11) to talk and discuss our #CimentBasCarbone. Today, come and attend our conference, Joffre room, at 10:30 a.m. on the theme: “Low-carbon concrete: ECOCEM solutions, feedback from 3 key partners” https://t.co/acdc4htpcu
# number of translated text is: 127
# row index is 1449
# translated text is: @le_egar Bravo! Who wants a harder one?😌 https://t.co/7Jc5cw0zXp
# number of translated text is: 128
# row index is 1450
# translated text is: @sahiim_ ⚡️The tension in this episode⚡️
# number of translated text is: 129
# row index is 1451
# translated text is: @sahiim_ Our heart swings https://t.co/gk4jV2aDOP
# number of translated text is: 130
# row index is 1452
# translated text is: “A tireless servant of the State, Mr. Roussely never stopped defending French industry. At the head of EDF, he led major transformations at the dawn of the 21st century. My thoughts are with his loved ones and those who worked alongside him.” Luc Rémont https://t.co/492xyB37Or
# number of translated text is: 131
# row index is 1453
# translated text is: @JVCom it’s a UP⬆️💡for ecology️
# number of translated text is: 132
# row index is 1455
# translated text is: Carried out every 10 years, the ten-year inspection is a real highlight in the life of a reactor with a dense maintenance and control program. In Civaux, it marks the 20th anniversary of reactor 1, the safety of which has been further improved. https://t.co/7JICtO7glM
# number of translated text is: 133
# row index is 1456
# translated text is: In October 2021, it was on this reactor that the phenomenon of stress corrosion was detected on certain portions of piping during scheduled checks. https://t.co/F1mxHjl49H
# number of translated text is: 134
# row index is 1457
# translated text is: This is a known phenomenon in the industry and can be detected by carrying out specific ultrasonic checks carried out preventively. After checks and expertise, 44 meters of pipes were replaced. https://t.co/6saepqXTxF
# number of translated text is: 135
# row index is 1458
# translated text is: The Civaux nuclear power plant is the most recent in France. It has an installed capacity of 1450MW per reactor, these are the most powerful reactors in the nuclear fleet. They produce electricity for around 3.3 million people. https://t.co/9AMde1ZvYM
# number of translated text is: 136
# row index is 1459
# translated text is: [THREAD] EDF and the Government of Andorra extend the collaboration agreement in favor of the Principality's energy transition and open new avenues of collaboration.
# number of translated text is: 137
# row index is 1460
# translated text is: This partnership offers a framework for the Principality of Andorra to fight against global warming by moving towards low-carbon electricity production through concrete actions.
#
# @FEDA_Andorra
# https://t.co/yO6hQGYmaD
# number of translated text is: 138
# row index is 1461
# translated text is: In addition to production solutions, it also enables the development of energy efficiency programs and the deployment of smart meters. Through this partnership, we reaffirm our desire to build a low-carbon and responsible energy model.
# number of translated text is: 139
# row index is 1462
# translated text is: @Sham_Rock71 Quite a twist of fate ⚡️ https://t.co/EFUvUlrfw1
# number of translated text is: 140
# row index is 1463
# translated text is: @RebeuDeter It's not too late for you to become the Goat 😎 of Minecraft with our #Carbonfighters datapack 👇 https://t.co/LsP4P1yVyP
# number of translated text is: 141
# row index is 1464
# translated text is: @epicsefy @RebeuDeter We see that our #CarbonFighters datapack is making people happy! To test it 👉  https://t.co/93nsH95N5C
# number of translated text is: 142
# row index is 1465
# translated text is: @JeanPaulepanda Our employees are talented!
# number of translated text is: 143
# row index is 1466
# translated text is: @le_gorafi A power station at home? Easy ! Install the #CarbonFighters datapack on Minecraft 😎👇
# https://t.co/LsP4P1yVyP
# number of translated text is: 144
# row index is 1467
# translated text is: To all students: may fate be favorable to you! 😁
# #enJeuxdAvenir2024 https://t.co/lKhca3zmt8 https://t.co/UsGBaoY2k7
# number of translated text is: 145
# row index is 1468
# translated text is: @Sat_lys the secret is out 👀 https://t.co/qewJBEOhGT
# number of translated text is: 146
# row index is 1471
# translated text is: @bennocap To open an electricity contract with us in a few clicks 😉👉 https://t.co/Rc2RETV7va
# number of translated text is: 147
# row index is 1472
# translated text is: @bennocap We leave this conversation neither seen nor known 😅 https://t.co/XVr8tGmrN2
# number of translated text is: 148
# row index is 1473
# translated text is: Grandma's advice >>>>
# #UsefulGestures https://t.co/9PY4WK3cE9
# number of translated text is: 149
# row index is 1474
# translated text is: This morning, @EDFofficiel unveils its 2022 annual results. A first for Luc Rémont, CEO of the Group since last November. Many media responded to the invitation. #tread ⬇️ https://t.co/dBShckzN23
# number of translated text is: 150
# row index is 1475
# translated text is: Since taking office, Luc Rémont has been in the field, in contact with those who make EDF. He was able to see the remarkable mobilization of the teams during the winter. https://t.co/Mi9GiGBNuW
# number of translated text is: 151
# row index is 1476
# translated text is: In 2022, the Group's EBITDA is strongly penalized by the drop in nuclear production and the exceptional regulatory measures put in place in France last year. The details of the results can be discovered here 👇 https://t.co/yMxMp05j1Z
# number of translated text is: 152
# row index is 1477
# translated text is: EDF has faced many challenges and has enjoyed great success in France and internationally. A look back at the highlights of 2022 👇 https://t.co/BXTIRfUuoc
# number of translated text is: 153
# row index is 1478
# translated text is: Luc Rémont speaks about 2023
# “Today, our priority is the recovery of EDF and I am convinced that all the actions underway will bear fruit. I can already talk about the successes that we will achieve in 2023” https://t. co/lUle25KnOM
# number of translated text is: 154
# row index is 1479
# translated text is: "With a view to improving the group's financial trajectory, I decided with the executive committee to launch 4 operational excellence projects at the start of the year." adds Luc Rémont https://t.co/ygde7nwkjs
# number of translated text is: 155
# row index is 1480
# translated text is: Come and chat with our employees and discover exciting jobs 🤩
#
# From February 23 to 26, EDF will be present at the Lyon edition of #VivaFabrica 👇
#
# https://t.co/k8icWS9XUb https://t.co/OngyFcnhCo
# number of translated text is: 156
# row index is 1481
# translated text is: Industry and young people, are they two? Answer in this video 👇 https://t.co/ITNdPelQNe
# number of translated text is: 157
# row index is 1483
# translated text is: @energiedusport @LaffontPerrine .@LaffontPerrine, one word: https://t.co/sIN40FoSlt
# number of translated text is: 158
# row index is 1485
# translated text is: @PatrickAdemo Pikachu ⚡️
# number of translated text is: 159
# row index is 1486
# translated text is: @spotifyfrance @MisterVonline @juiceakakanda @xSqueeZie Still missing a small solar panel? 😁☀️
# number of translated text is: 160
# row index is 1487
# translated text is: A competition committed to the climate and the environment by halving its carbon emissions?
# 👉 This is the common objective set with @Paris2024 for a new Games model
#
# Want to talk about it? Ask all your questions and see you on March 14 for the 2nd episode of #ExAequo 📢 https://t.co/1ytKL0mYKl
# number of translated text is: 161
# row index is 1488
# translated text is: Memorable @Paris2024 Games, that’s what we all want 🙌🏅
# But are responsible Games possible?
#
# To find out, follow our #live with @Vanessalemoigne, @alainbernard, @franckchauveau1 and @Amadea_k 🎙️
#
# And we don’t forget the reminder 🔔👇
# https://t.co/t6QARzfCvC
# number of translated text is: 162
# row index is 1489
# translated text is: #ExÆquo returns Tuesday with @Vanessalemoigne for an episode on the responsible commitments of @Paris2024!
# Don't miss this #Live, we're offering you tickets for the Olympic Games:
# 👉Subscribe to @EDFofficiel
# 👉Connect to #Spaces to enter the draw ⤵️
# number of translated text is: 163
# row index is 1490
# translated text is: The @Paris2024 Olympic Games are getting closer!
# And the new episode of our #ExAequo series even more!
#
# Meet at 7 p.m. with @Vanessalemoigne, @alainbernard, @Amadea_k and @franckchauveau1 to get their opinions and answers to your questions 👉 https://t.co/z5jP0fA4dI https://t.co/cpSuuv4yWT
# number of translated text is: 164
# row index is 1491
# translated text is: #EDF announces the appointment of Brice Bohuon to the Executive Committee of the EDF Group as Group Executive Director, in charge of the General Secretariat.
# number of translated text is: 165
# row index is 1492
# translated text is: The new episode of #ExAequo is in a few minutes! ⏱️ https://t.co/z5jP0fA4dI
# number of translated text is: 166
# row index is 1494
# translated text is: It's not 1, nor 2, nor 3... But 5 crystal globes 🤩 Well done @LaffontPerrine 👏 https://t.co/I09DXR35V5
# number of translated text is: 167
# row index is 1495
# translated text is: By how much will @Paris2024 divide the carbon footprint of the Olympic and Paralympic Games ❓
# number of translated text is: 168
# row index is 1496
# translated text is: If you don't have the answer, it's hidden here 🙈 Listen again to our #TwitterSpaces 👇
# https://t.co/4Y0wDRqmBi
# number of translated text is: 169
# row index is 1497
# translated text is: What is a STEP?
# Little tutorial 👇
# https://t.co/P5fB68NDbG
# number of translated text is: 170
# row index is 1498
# translated text is: To explore the subject, see you Friday at 12:15 p.m. for our #Spaces with our experts, hosted by Virginie Hilssone-Lévy 🎙️
#
# 👉https://t.co/OwMOtOMiik
# number of translated text is: 171
# row index is 1500
# translated text is: 🎙🔴 We are online and live for our #Spaces on the subject of hydroelectricity in the face of climate change
#
# Join us👇
# https://t.co/qEYjs4FpmJ
# number of translated text is: 172
# row index is 1501
# translated text is: The EDF group and Maple Power win a one gigawatt offshore wind project off the coast of Normandy.
#
# This new offshore wind project will provide France with competitive and renewable electricity, contributing to the country's carbon neutrality objective. 👇
# number of translated text is: 173
# row index is 1502
# translated text is: Working on the deployment of an innovative project offering reliable and #carbon-free energy? 🍃
#
# This is what Capucine is doing by participating in the development of small modular power plants ☢️
#
# Discover his job in this episode of #ElectricTeam ⚡️ https://t.co/Zbv5NmvtVd
# number of translated text is: 174
# row index is 1503
# translated text is: @Paris2024 We will learn it but in the meantime, we will play it easier 😅
# #SOP2023 https://t.co/xMixaPiGcI
# number of translated text is: 175
# row index is 1504
# translated text is: In partnership with Le Souvenir français, to coincide with the law of April 8, 1946 (nationalization of electricity and gas), EDF will now rekindle the Flame under the Arc de Triomphe every April 8. It has shined since 1923 in infinite respect for French soldiers. https://t.co/BYE19PbxDX
# number of translated text is: 176
# row index is 1505
# translated text is: In 2022, the #Mediator of the EDF group has 👇
# ✅ shortened the average instruction time by 11 days
# ✅ successfully completed files in 85% of cases.
#
# #DLDMars
# number of translated text is: 177
# row index is 1511
# translated text is: EDF announces the appointment of Caroline Chanavas as Deputy Director of Human Resources. She will join the Group on April 17, 2023.
# number of translated text is: 178
# row index is 1512
# translated text is: 🗣️ “The company offers the possibility of a rich and varied career”
#
# After 7 years as a #design engineer at #EDF, Farida is now flourishing as a #buyer 👩‍💻
#
# Discover his daily life in this episode of #ElectricTeam ⚡️
#
#  https://t.co/f5Hc7Mk5VE
# number of translated text is: 179
# row index is 1513
# translated text is: @AurelyMariette Good evening, to help you as best as possible, can you send us your contact details and your customer number in DM via the link https://t.co/CXHEEcXvxk? Mylène, your EDF advisor
# number of translated text is: 180
# row index is 1514
# translated text is: @JimMuganza Find all our offers here 👇
# https://t.co/jtdbhgCCni
# number of translated text is: 181
# row index is 1515
# translated text is: Yesterday morning, visit to Hinkley Point C with @AgnesRunacher @grantshapps and Luc Rémont. This visit highlighted the synergies enabled by cooperation between the 🇫🇷 and the 🇬🇧. #Nuclear will play a major role in the energy transition in Europe. #netzero https://t.co/Hj5Qy5djys
# number of translated text is: 182
# row index is 1516
# translated text is: @jul And the bonus tracklist. https://t.co/05CNOvEAuE
# number of translated text is: 183
# row index is 1517
# translated text is: The #alternation at #EDF means a 95% chance of obtaining your diploma 🧑‍🎓👩‍🎓
#
# That's not enough to convince you? 👇
#
# See you Wednesday at 12:30 p.m. with @mrlechat94 for a new #EDFRéponde ⚡️
#
# #DLDAvril @EDFRecrute
#
# https://t.co/tmEuPFJD1b
# number of translated text is: 184
# row index is 1518
# translated text is: Any plans for tomorrow?
#
# We have an idea for you 👇
#
# See you at 12:30 p.m., for a brand new #EDFRepond on #alternation, with @LucieCMN, @emmanuelraynal4 and @mrlechat94 ⚡️
#
# #DLDAvril @edfrecrute
# number of translated text is: 185
# row index is 1519
# translated text is: Did you miss it? 😬
#
# ...
# number of translated text is: 315
# row index is 1674
# translated text is: Contrary to their name, heat pumps can also cool and dehumidify the environment.
# If combined with a photovoltaic system, the advantages increase considerably.
# Discover other tips for saving in summer and all year round on ViviElettrico: https://t.co/YCLeFGHnaW https://t.co/ucs1SsoSZc
# number of translated text is: 316
# row index is 1675
# translated text is: In our Enel Spaces we are always ready to welcome you with a smile. Roberto and Vincenza, consultants at the Spazio Enel in Naples, testify to this. Find the store closest to you and come visit us: https://t.co/W2p55gAXUK https://t.co/lWlon25iJJ
# number of translated text is: 317
# row index is 1676
# translated text is: ☀ Participate in “Three steps into sustainability with ENELPREMIA WOW!” and try to win fantastic prizes every day. If you are not yet registered, sign up for ENELPREMIA WOW! 👉https://t.co/x2eg8KxiTa https://t.co/d197EuhxBJ
# number of translated text is: 318
# row index is 1677
# translated text is: People who go to Enel Spaces always find kindness and empathy.
# Introducing Iolanda, consultant at the Enel Space in Bari.
# Come and visit us in the store closest to you: https://t.co/W2p55gAXUK https://t.co/uaWa4Gfkvo
# number of translated text is: 319
# row index is 1678
# translated text is: @masman007 @a_meluzzi Hi, thank you for the report. We would like to point out that Enel Energia does not carry out this type of unfair practice and that it is also prohibited for our partners. The Company pays the utmost attention to similar cases by reporting them to the AG. For info: https://t.co/anADqIYbUR
# number of translated text is: 320
# row index is 1679
# translated text is: With Enel Energia, simplicity takes shape, even in the bill! 📄
# Now it is even clearer, transparent and immediate 🤓.
# Discover all the news 👉 https://t.co/iHKjqamMdw https://t.co/c2b3A0Jy9K
# number of translated text is: 321
# row index is 1680
# translated text is: Discover Enel Flex, the three-hourly offer that saves you in the evenings and on holidays. Flexible and digital, it adapts to market changes.
# 👉https://t.co/73MFGCXzAc https://t.co/e7Y4OKQxkY
# number of translated text is: 322
# row index is 1681
# translated text is: 🫧 Participate in “Three steps into sustainability with ENELPREMIA WOW!” and try to win fantastic prizes every day. If you are not yet registered, sign up for ENELPREMIA WOW! 👉 https://t.co/x2eg8KxQII https://t.co/lLVzEhl6LI
# number of translated text is: 323
# row index is 1682
# translated text is: When a company like @PianteFaro has to choose the right energy partner, it looks for those who can fuel dreams and ambitions. Look at our Business Story. 👇
#
# Message also containing promotional content from @EnelXItalia and @enelxwayitalia https://t.co/99UnISv9p5
# number of translated text is: 324
# row index is 1683
# translated text is: A 24-hour marathon 🕐 to remember the importance of zero value when talking about CO2 emissions. Precisely today, we at Enel Energia renew our commitment to safeguarding the planet. 🌍
# #ZeroEmissionsDay #CarbonNeutrality https://t.co/zMZAWNkbKV
# number of translated text is: 325
# row index is 1684
# translated text is: Having a reliable partner, like Enel Energia, means having the time to focus on your business to build a better future.
# Mario Faro, CEO of @PianteFaro, tells us about it. 🪴
# Message also containing promotional content from @EnelXItalia and @enelxwayitalia https://t.co/yJvUtPJ9XB
# number of translated text is: 326
# row index is 1685
# translated text is: 🫧 Participate in “Three steps into sustainability with ENELPREMIA WOW!” and try to win fantastic prizes every day. If you are not yet registered, sign up for ENELPREMIA WOW! 👉 https://t.co/x2eg8KxiTa https://t.co/gnaAKXcFf0
# number of translated text is: 327
# row index is 1686
# translated text is: Our stainless energy is the key to CPC INOX's success.
# Find out how we help a large Italian company grow in our Business Story. 👇
# Message also containing promotional content from @EnelXItalia. https://t.co/xWkLkenpMl
# number of translated text is: 328
# row index is 1687
# translated text is: Cooking with an induction hob, in addition to the economic advantages, brings others, such as saving on CO2 emissions, more uniform cooking, more precise temperature regulation and greater safety.
# Find out more about ViviElettrico: https://t.co/ybOpbTS63O https://t.co/HYThnjX9RM
# number of translated text is: 329
# row index is 1688
# translated text is: Quality and speed are the winning values ​​for a successful company. Alberto Schiavo, CPC Inox Sales Director, tells us about it. Watch the interview. 👇
# Message also containing promotional content from @EnelXItalia. https://t.co/scfgoiql2o
# number of translated text is: 330
# row index is 1689
# translated text is: We are the energy that helps you achieve winning goals and break new records. 🏎
# This is why @SparcoOfficial has chosen us as its energy partner.
# Look at our Business Story. 👇
#
# Message also containing promotional content from @EnelXItalia and @enelxwayitalia. https://t.co/rQwUm9z7Fv
# number of translated text is: 331
# row index is 1690
# translated text is: “Energy for a company is like the nervous system for a human being.”
# Watch the interview with Aldino Bellazzini, President and CEO of @SparcoOfficial
# 👉 https://t.co/rdEXcSEUHd
# Message also containing promotional content from @EnelXItalia and @Enelxwayitalia
# number of translated text is: 332
# row index is 1691
# translated text is: With Choose Today from Enel Energia you have the list price of the energy component blocked for the first 12 months.
# Find out more 👉 https://t.co/RClvrRomW9 https://t.co/MoLIZAQcWP
# number of translated text is: 333
# row index is 1692
# translated text is: At Creazioni Digitali our energy ignites creativity and illuminates ideas.
# Check out this and the other Business Stories.
# 👉 https://t.co/fh5crLgRlQ
# Message also containing promotional content from @EnelXItalia. https://t.co/gUuRnU991Q
# number of translated text is: 334
# row index is 1693
# translated text is: “Using energy in a conscious and sustainable way is a source of pride”.
# @LuciniRoberto, CEO Creazioni Digitali, talks about how our energy mixes with creativity and sustainability. https://t.co/fh5crLgRlQ
# Message also containing promotional content from @EnelXItalia. https://t.co/F5Peh16LN5
# number of translated text is: 335
# row index is 1694
# translated text is: 🎉When an offer is convenient, efficient and moves with you, it is definitely Formidable👍.
# Find out more 👉 https://t.co/k09D1GZiu4
# #TuttoEnelFormidabile https://t.co/RzwfPsFrIP
# number of translated text is: 336
# row index is 1695
# translated text is: Have you ever thought that an offer on electric mobility 🚘 could surprise you? Enel's Formidable Dual Mobility will take care of it 👍 with Light, Waybox and free up to 10,000 km. Only until December 31st.
# Find out more at https://t.co/k09D1GZiu4
# #TuttoEnelFormidabile https://t.co/67cpATDgyI
# number of translated text is: 337
# row index is 1696
# translated text is: With ENELPREMIA WOW! your points last one more year! Collect them until 8/31/24 and claim rewards until 10/29/24. Your WOOOOW is even longer! 🤩 https://t.co/WQiLa5ncGh
# Complete regulations and methods of participation on https://t.co/lR1pMnPLrA and the Enel Energia App. https://t.co/TJwLsArHlj
# number of translated text is: 338
# row index is 1697
# translated text is: No wonder! With the Formidabile Fotovoltaico offer, you have a 3 kW photovoltaic system for €65/month for 120 months. 🌞 And if you add Formidabile Luce you get €100 annual bonus on your bill for 2 years. Only until December 31st.
# 👉 Find out more at https://t.co/k09D1GZiu4 https://t.co/4LUibpOMnD
# number of translated text is: 339
# row index is 1698
# translated text is: On November 21st, turn on Black Friday with Enel Energia, the offer you were looking for is arriving. 👀
# Find out more 👉 https://t.co/Prm0kWoiUU https://t.co/R0Df8KJdhn
# number of translated text is: 340
# row index is 1699
# translated text is: Can't you help but be amazed😲?
# I believe it, it's a FORmidable trio 👍.
# If you choose Formidabile Luce, Gas e Fibra from Enel you have up to €400 annual bonus on your bill for 2 years. Only until December 31st.
# Find out more at https://t.co/k09D1GZiu4 https://t.co/GxaXk5wWgZ
# number of translated text is: 341
# row index is 1700
# translated text is: There's an offer on electric mobility that you can't help but… hum! 🎵 It's Formidable Dual Mobility from Enelcon Luce, Waybox and free up to 10,000 km 👍. Only until December 31st. Find out more at https://t.co/k09D1GZQjC https://t.co/Vh6QaSybmH
# number of translated text is: 342
# row index is 1701
# translated text is: ■With Black Friday E-light Luce and E-light Gas are even more advantageous!■ Discover the details of the offers, what are you waiting for? 👉 https://t.co/er2f9ItPdH https://t.co/LT92TG38tp
# number of translated text is: 343
# row index is 1702
# translated text is: 🤩 Let yourself be surprised by #ENELPREMIAWOW! Choose between #Veepee, #AcquaAlma and #Treedom.
# Download the app 👉 https://t.co/ZqxDCTnDqV https://t.co/0iKxBzBn3a
# number of translated text is: 344
# row index is 1703
# translated text is: You won't believe your eyes🤓! This is the Formidable Photovoltaic offer, you have a 3 kW photovoltaic system for €65/month for 120 months. And if you add Formidabile Luce you get a €100 annual bonus on your bill for 2 years. Only until December 31st. 👍
# https://t.co/k09D1GZiu4 https://t.co/R8LPwV3HQW
# number of translated text is: 345
# row index is 1704
# translated text is: You'll be left speechless!😦 It's the FORMIDABLE TRIO offer. If you choose Formidabile Luce, Gas e Fibra from Enel Energia you have up to €400 annual bonus on your bill for 2 years. Only until December 31st. https://t.co/k09D1GZiu4 https://t.co/nzuKcGnQM4
# number of translated text is: 346
# row index is 1705
# translated text is: No wonder! With the Formidabile Fotovoltaico offer, you have a 3 kW photovoltaic system for €65/month for 120 months. 🌞 And if you add Formidabile Luce you get €100 annual bonus on your bill for 2 years. Only until December 31st. 👉 Find out more at https://t.co/k09D1GZiu4 https://t.co/MbrzFcjCY8
# number of translated text is: 347
# row index is 1706
# translated text is: Have you ever thought that an offer on electric mobility 🚘 could surprise you? Enel's Formidable Dual Mobility will take care of it 👍 with Light, Waybox and free up to 10,000 km. Only until December 31st. Find out more at https://t.co/k09D1GZiu4 #TuttoEnelFormidabile https://t.co/2m48tyvodd
# number of translated text is: 348
# row index is 1707
# translated text is: 🎄Participate in the competition “A sustainable Christmas with ENELPREMIA WOW!” and try to win one of the Dyson products up for grabs every day.
# Download the app 👉 https://t.co/BDhTODrOHt https://t.co/dCy1i1SFpV
# number of translated text is: 349
# row index is 1708
# translated text is: A new browsing experience and many new features to manage your supplies, discover our best offers, receive assistance, participate in the ENELPREMIA WOW! loyalty program and so on.
# Download or update it now📱
# https://t.co/PdE0tjDGUn https://t.co/2XTJ8DjYFH
# number of translated text is: 350
# row index is 1709
# translated text is: Everyone has questions, but now so many answers!
# The #SpazioDelleRisponse is born, where every week we will give you one to help you better understand the world of energy.
# What you can do with our App❓Find out in our first video.👇
# https://t.co/PdE0tjDGUn https://t.co/rIvLaEtqoa
# number of translated text is: 351
# row index is 1710
# translated text is: Can't you help but be amazed😲? I believe it, it's a FORmidable trio 👍.
# If you choose Formidabile Luce, Gas e Fibra from Enel you have up to €400 annual bonus on your bill for 2 years. Only until December 31st.
# Find out more at https://t.co/k09D1GZQjC https://t.co/krCHUk1yfF
# number of translated text is: 352
# row index is 1711
# translated text is: You often wonder how to best use energy❓
# The #SpazioDelleRisponse has many solutions for you, including for this question. Watch the video and improve your daily drinking habits. 💡
# 👉 https://t.co/RtulO73Sqt https://t.co/4uArOdNKcd
# number of translated text is: 353
# row index is 1712
# translated text is: 🎄Participate in the competition “A sustainable Christmas with ENELPREMIA WOW!” and try to win one of the Dyson products up for grabs every day.
# Download the app 👉 https://t.co/BDhTODrOHt https://t.co/UOmJO8JZvx
# number of translated text is: 354
# row index is 1713
# translated text is: Get ready for the end of the Greater Protection Service. Switching to the Free Market will be very simple with Enel Energia. 👉 https://t.co/iRsGbjfum2
# The end of the Greater Protection Service for electricity provided for non-vulnerable customers is currently set for 01/07/24. https://t.co/SynWqSGF8b
# number of translated text is: 355
# row index is 1714
# translated text is: 🤩 Experience a special Christmas with #ENELPREMIAWOW! Choose between #infinity+, #go4alltouroperator and #Feltrinelli. Download the app 👉https://t.co/t8htIUaKhP https://t.co/XcVkyxSWBl
# number of translated text is: 356
# row index is 1715
# translated text is: 2023 was a year full of energy, let's relive the best moments together!
# See you again in 2024. ✨ https://t.co/9I9Nvtg6vd
# number of translated text is: 357
# row index is 1887
# translated text is: @nomadycat Our local office is best equipped to answer questions about product availability in your local market. You can find contact information at this link: https://t.co/1C7CfKUHhE
#
# Please note that our offices are not open in the evenings or on weekends.
# number of translated text is: 358
# row index is 1897
# translated text is: @ladylestrangge Hello - Please contact our team in Brazil to see if there are any patient assistance programs available. You will find all available contact information for this team here: https://t.co/ef56pSsl3N
# number of translated text is: 359
# row index is 1909
# translated text is: @shex47171391 Hi, We don't have a Whatsapp number. If you let me know what country you are in, I may be able to provide a link to contact information for our local office, where they can discuss your concerns.
#
# -Crystal
# number of translated text is: 360
# row index is 1914
# translated text is: @shex47171391 We have recently changed our business model in Iraq. Going forward, we aim to supply medicines and vaccines from GSK directly to the Ministry of Health, or in partnership with transnational organizations. You will need to talk to the Department of Health about medications.
# number of translated text is: 361
# row index is 1919
# translated text is: @flyriviera In the interest of patient safety, GSK would like more information about the experience you reported. Contact GSK at https://t.co/Me3riY9QER
# number of translated text is: 362
# row index is 2003
# translated text is: @gabborosas Our local office in Mexico is best equipped to answer questions about product availability in your local market: https://t.co/fUKrhsGfzX
#
# Please note that our offices are not open at night or on weekends.
# number of translated text is: 363
# row index is 2057
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 4
#       2 for index, row in tqdm(no_english.iterrows(), total=len(no_english)):
#       3     print(f'row index is {index}')
# ----> 4     translated = translator.translate(row['text'], src=row['lang'], dest="en").text
#       5     print(f'translated text is: {translated}')
#       6     english_texts.append(translated)
#
# File c:\Users\valen\Anaconda3\Lib\site-packages\googletrans\client.py:192, in Translator.translate(self, text, dest, src, **kwargs)
#     190         src = LANGCODES[src]
#     191     else:
# --> 192         raise ValueError('invalid source language')
#     194 if dest not in LANGUAGES:
#     195     if dest in SPECIAL_CASES:
#
# ValueError: invalid source language

# %%
no_english.loc[2057]
# Out:
# username                                                    gsk
# lang                                                         in
# text          @iarumk Halo - Haleon mengambil alih divisi la...
# created_at                             2023-04-17T15:39:56.000Z
# Name: 2057, dtype: object

# %%
en_texts
# Out:
# ['.@ACCIONAEnergia is focused on the greatest photovoltaic challenge developed in its 30 years of life in the renewable sector: building 🇺🇸 solar plants with a combined power equivalent to a nuclear power plant, with more than two million panels 👇https://t .co/HPfeti7ABI',
#  'Two islands connected by a huge bridge 🌉\n\nBut not just any one: 2.5 km long with a 650 m cable-stayed main structure. We are talking about the Cebu cable-stayed bridge, one of our largest engineering works in Southeast Asia 👇\n\nhttps://t.co/CQywj6hV2g https://t.co/Yfv7RU8rfQ',
#  "Episode 2 of the docuseries '#LaLuzQuePermanece' is now available on the social channels of @acciona_org. Don't miss the mysteries of the Amazon jungle and the commitment of the Copal Urco community to renewable energies 👇 https://t.co/Fmpu2s8bxi",
#  "𝐀𝐥𝐞𝐣𝐚𝐧𝐝𝐫𝐨 𝐁𝐞𝐢𝐯𝐢𝐝𝐞, Director of Digital Infrastructure Transformation, will be present tomorrow, Wednesday, November 15, at 9:00 am, in Cantabria 🇪🇸 giving a presentation on Industrial Connectivity 📅📢 Don't miss it!\n\nAll the details here ⤵",
#  'City bees collect much more than pollen\n\n🐝🐝🐝\n\nThese pollinators trap samples of bacteria and microbes that allow us to know the state of health of the environment 🏙️⚕️ Find out how they do it 👇 https://t.co/DoBjqNi6Dk',
#  '@CarlosaUruetav Here are some of them https://t.co/UyTN84UKiP and https://t.co/XKJe3SPKDQ Greetings!',
#  "📅 Tomorrow, Manuel Navarro, Director of Water for Agriculture, participates in the @Tecniberia Conference, sharing his experience in Session II, Water Table ''𝐀𝐠𝐫𝐢𝐜𝐮𝐥𝐭𝐮𝐫𝐚, 𝐫𝐠𝐢́𝐚'', along with other professionals in the sector 🗣️\n\n💦 More information here:",
#  'We have built more than 5,000 km of highways, highways and roads in recent years around the world: Australia, Spain, Canada, Denmark....🌏🛣️ A world map of increasingly innovative and sustainable smart roads 👉 https:// t.co/lYFJ8wo0PV https://t.co/UEd6g7JNsh',
#  "Good news for the wind sector! The project combines our experience in the use of composite materials, @ACCIONAEnergia's access to disused wind turbine blades and @renercycle's activities in the dismantling of wind turbines\nhttps://t.co/1xNBfSZ1Nv",
#  'The @ACCIONA_ORG foundation extends its renewable and affordable supply service and already benefits more than 1,600 people in the province of Coquimbo\n\n🇨🇱🇨🇱🇨🇱\n\nhttps://t.co/TWAljGdc5u',
#  'Ultrasounds to the rescue 🦹\u200d♀️🦸\u200d♂️\n\nAccording to the latest research, chemical residues that accumulate in groundwater and wastewater 💦 could be cleaned using ultrasound 👇 https://t.co/LS8FLUW6Dw',
#  'This system will calculate the Water footprint in the @COE_es facilities, promote the reduction of water consumption and replicate the model in other sports organizations 👇💦\n\nhttps://t.co/IbtKG9tb5I',
#  'The main challenge is to develop correct water management based on climate adaptation and mitigation. We take on the challenge of extending a positive water footprint through the design of regenerative water infrastructure\nhttps://t.co/IbtKG9tIVg',
#  'What is reverse osmosis desalination? 💦\n\nIt is the most widespread and advanced desalination system in the world 🌏 Its implementation represents more than 60% compared to the rest of the methods 👇 https://t.co/lKRjLHUL4U',
#  '.@ACCIONAEnergia is simultaneously constructing four photovoltaic projects in 🇺🇸 that add up to 1.3 GWp of peak power. The new facilities will generate clean energy equivalent to the consumption of more than 210,000 American homes 🏡 https://t.co/I0f7Jm69CB']

# %%
len(en_texts)
# Out:
# 798

# %%
for idx, text in zip(indexes, en_texts):
    no_english.loc[idx, 'en_text'] = text

# %%
no_english
# Out:
#      username lang                                               text  \
# 138   acciona   es  .@ACCIONAEnergia está volcada en el mayor reto...
# 139   acciona   es  Dos islas conectadas por un inmenso puente 🌉\n...
# 140   acciona   es  Ya está disponible en los canales sociales de ...
# 141   acciona   es  𝐀𝐥𝐞𝐣𝐚𝐧𝐝𝐫𝐨 𝐁𝐞𝐢𝐯𝐢𝐝𝐞, Director de Transformación ...
# 142   acciona   es  Las abejas de la ciudad recogen mucho más que ...
# ...       ...  ...                                                ...
# 6088   vestas   da  🇩🇰 / in Danish:\nVi har været med til at start...
# 6089   vestas   da  🇩🇰/ in Danish: I Danmark har vi besluttet at f...
# 6108   vestas  und  🇩🇰: #dkbiz #dkpol #dkgreen https://t.co/9BpJhy...
# 6115   vestas   da  🇩🇰 (in Danish): Tak for besøget på vores fabri...
# 6124   vestas   da  🇩🇰: I år der indtil nu indgået købsaftaler på ...
#
#                     created_at  \
# 138   2023-11-11T11:30:00.000Z
# 139   2023-11-12T11:00:00.000Z
# 140   2023-11-14T14:03:22.000Z
# 141   2023-11-14T16:21:46.000Z
# 142   2023-11-14T21:00:01.000Z
# ...                        ...
# 6088  2023-09-08T09:49:50.000Z
# 6089  2023-09-13T11:41:01.000Z
# 6108  2023-10-04T07:38:30.000Z
# 6115  2023-11-10T08:47:32.000Z
# 6124  2023-12-12T17:01:53.000Z
#
#                                                 en_text
# 138   .@ACCIONAEnergia is focused on the greatest ph...
# 139   Two islands connected by a huge bridge 🌉\n\nBu...
# 140   Episode 2 of the docuseries '#LaLuzQuePermanec...
# 141   𝐀𝐥𝐞𝐣𝐚𝐧𝐝𝐫𝐨 𝐁𝐞𝐢𝐯𝐢𝐝𝐞, Director of Digital Infrast...
# 142   City bees collect much more than pollen\n\n🐝🐝🐝...
# ...                                                 ...
# 6088  🇩🇰 / in Danish:\nWe have helped start the Alli...
# 6089  🇩🇰/ in Danish: In Denmark, we have decided to ...
# 6108  🇩🇰: #dkbiz #dkpol #dkgreen https://t.co/9BpJhy...
# 6115  🇩🇰 (in Danish): Thank you for visiting our fac...
# 6124  🇩🇰: This year, until now, purchase agreements ...
#
# [798 rows x 5 columns]

# %%
for index, row in no_english.iterrows():
    if index in df.index:
        df.loc[index, 'text'] = row['en_text']
df
# Out:
#           username lang                                               text  \
# 0     abbgroupnews   en  New ABB E-mobility home charging solution help...
# 1     abbgroupnews   en  ABB #technology to facilitate #energyefficienc...
# 2     abbgroupnews   en  Better decisions for a greener data center! Ho...
# 3     abbgroupnews   en  ABB Formula E Season 9 goes green in Mexico!\n...
# 4     abbgroupnews   en  The #ABB Decoded #podcast with Frank Muehlon i...
# ...            ...  ...                                                ...
# 6125        vestas   en  🌎: 2023 was the hottest year in recorded histo...
# 6126        vestas   en  🇪🇺: To deliver clean, affordable, and secure e...
# 6127        vestas   en  🌎 /🇬🇧 : In the making: one of the largest offs...
# 6128        vestas   en  🌎/🇬🇧: Partnering with @RWE_AG  to take the Nor...
# 6129        vestas   en  🇺🇸 Just in: Our largest order to date in the U...
#
#                     created_at en_text
# 0     2023-01-03T15:18:41.000Z     NaN
# 1     2023-01-10T09:57:29.000Z     NaN
# 2     2023-01-11T10:01:06.000Z     NaN
# 3     2023-01-12T09:09:45.000Z     NaN
# 4     2023-01-13T09:41:43.000Z     NaN
# ...                        ...     ...
# 6125  2023-12-13T16:03:45.000Z     NaN
# 6126  2023-12-19T15:32:30.000Z     NaN
# 6127  2023-12-20T15:13:16.000Z     NaN
# 6128  2023-12-22T11:16:00.000Z     NaN
# 6129  2023-12-27T20:31:45.000Z     NaN
#
# [6130 rows x 5 columns]

# %%
df = df.drop(columns=['en_text'])
df
# Out:
#           username lang                                               text  \
# 0     abbgroupnews   en  New ABB E-mobility home charging solution help...
# 1     abbgroupnews   en  ABB #technology to facilitate #energyefficienc...
# 2     abbgroupnews   en  Better decisions for a greener data center! Ho...
# 3     abbgroupnews   en  ABB Formula E Season 9 goes green in Mexico!\n...
# 4     abbgroupnews   en  The #ABB Decoded #podcast with Frank Muehlon i...
# ...            ...  ...                                                ...
# 6125        vestas   en  🌎: 2023 was the hottest year in recorded histo...
# 6126        vestas   en  🇪🇺: To deliver clean, affordable, and secure e...
# 6127        vestas   en  🌎 /🇬🇧 : In the making: one of the largest offs...
# 6128        vestas   en  🌎/🇬🇧: Partnering with @RWE_AG  to take the Nor...
# 6129        vestas   en  🇺🇸 Just in: Our largest order to date in the U...
#
#                     created_at
# 0     2023-01-03T15:18:41.000Z
# 1     2023-01-10T09:57:29.000Z
# 2     2023-01-11T10:01:06.000Z
# 3     2023-01-12T09:09:45.000Z
# 4     2023-01-13T09:41:43.000Z
# ...                        ...
# 6125  2023-12-13T16:03:45.000Z
# 6126  2023-12-19T15:32:30.000Z
# 6127  2023-12-20T15:13:16.000Z
# 6128  2023-12-22T11:16:00.000Z
# 6129  2023-12-27T20:31:45.000Z
#
# [6130 rows x 4 columns]

# %%
df.to_csv('df_for_topic_modelling.csv')
