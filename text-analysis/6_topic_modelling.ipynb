# %%
import re

import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
from nltk.tokenize import TweetTokenizer
from matplotlib import rcParams
from matplotlib.patches import Patch
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from sklearn.cluster import KMeans

# %%
#rcParams default settings
"https://matplotlib.org/stable/tutorials/introductory/customizing.html"

#rcParams settings
plt.style.use('ggplot')

rcParams['font.family'] = 'sans-serif'
rcParams['font.style'] = 'normal'

rcParams['figure.facecolor'] = 'white'

rcParams['savefig.bbox'] = 'tight'
rcParams['savefig.dpi'] = 300
rcParams['savefig.transparent'] = True

rcParams['axes.spines.right'] = False
rcParams['axes.spines.top'] = False
rcParams['axes.labelsize'] = 20
rcParams['axes.labelcolor'] = 'black'
rcParams['axes.edgecolor'] = 'grey'
rcParams['axes.linewidth'] = 3
rcParams['axes.facecolor'] = 'white'
rcParams['axes.titlepad'] = 4
rcParams['axes.titlesize'] = 20
rcParams['axes.spines.right'] = True
rcParams['axes.spines.top'] = True

rcParams['xtick.color'] = 'grey'
rcParams['ytick.color'] = 'grey'
rcParams['xtick.labelsize'] = 15
rcParams['ytick.labelsize'] = 15
rcParams['xtick.major.width'] = 2
rcParams['ytick.major.width'] = 0
rcParams['xtick.major.size'] = 5
rcParams['ytick.major.size'] = 0

rcParams['lines.linewidth'] = 3
rcParams['lines.markersize'] = 10

rcParams['legend.title_fontsize'] = 15
rcParams['legend.fontsize'] = 10

rcParams['grid.color'] = 'grey'
rcParams['grid.linewidth'] = 0.1

icefire_palette = sns.color_palette("icefire")
sns.set_palette(icefire_palette)

# %% [markdown]
# ## Topic Modelling Pipeline

# %%
df = pd.read_csv('cleaned_texts.csv', index_col=[0])

# %%
len(df)
# Out:
# 10333

# %%
df = df.loc[~df.cleaned_text.isna()]

# %%
len(df)
# Out:
# 10293

# %% [markdown]
# #### Text extraction

# %%
docs = df.cleaned_text.to_list()

# %% [markdown]
# #### Training procedure

# %%
model = BERTopic()

# %%
# Train model
topics, probs = model.fit_transform(docs)

# %%
model.visualize_documents(docs, hide_document_hover=True, hide_annotations=True)

# %%
model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1   4173                      -1_energy_building_learn_read
# 1        0    232                       0_train_rail_passenger_metro
# 2        1    205                       1_wind_turbine_farm_offshore
# 3        2    171                2_vessel_methanol_container_sailing
# 4        3    152                    3_brick_bricktastic_sound_build
# ..     ...    ...                                                ...
# 164    163     11           163_disability_accessible_visible_purple
# 165    164     11            164_visualization_booth_wall_innovation
# 166    165     11  165_ethic_integrityspeakupline_integrity_depar...
# 167    166     11                  166_emergency_bleeds_care_require
# 168    167     11                 167_episode_minute_premiere_season
#
#                                         Representation  \
# 0    [energy, building, learn, read, help, year, so...
# 1    [train, rail, passenger, metro, railway, fleet...
# 2    [wind, turbine, farm, offshore, blade, project...
# 3    [vessel, methanol, container, sailing, crew, g...
# 4    [brick, bricktastic, sound, build, click, play...
# ..                                                 ...
# 164  [disability, accessible, visible, purple, peop...
# 165  [visualization, booth, wall, innovation, persp...
# 166  [ethic, integrityspeakupline, integrity, depar...
# 167  [emergency, bleeds, care, require, clinician, ...
# 168  [episode, minute, premiere, season, master, fo...
#
#                                    Representative_Docs
# 0    [want enhance skill grow business myschneider ...
# 1    [train transport passenger seated accessibilit...
# 2    [contract includes supply installation service...
# 3    [thanks sharing news soon welcome fleet world ...
# 4                     [brick help, brick brick, brick]
# ..                                                 ...
# 164  [remember disability visible provide accessibl...
# 165  [thank give perspective compare others head da...
# 166  [thank contacting please reach integrity speak...
# 167  [major bleeds including intracerebral severe g...
# 168  [season master premiere tonight fourget rest s...
#
# [169 rows x 5 columns]
